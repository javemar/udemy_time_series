# %%
import  pandas as pd
import numpy as  np
import os
os.chdir(r"/home/javemar/Documents/udemy/Python for Time Series/Course Resources/UDEMY-TSA-FINAL/UDEMY_TSA_FINAL/Data"
    )
from datetime import datetime
# %matplotlib inline

# %%
df = pd.read_csv("starbucks.csv",  parse_dates=True,  index_col="Date")

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name=u'Date', length=1006, freq=None)

# %% [markdown]
# The index must be a  date if you want to follow along

# %%
df.plot()#Take in account scales..

# %%
df.Close.plot();

# %%
df.Volume.plot()

# %% [markdown]
# ## Plot Formating

# %%
title = "Title"
ylabel =  "ylabel"
xlabel = "xlabel"

df.Close.plot(figsize=(12,6) ,title=title)

# %%
ax = df.Close.plot(figsize=(12,6), title=title)
ax.autoscale(tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0,0.5,'ylabel'), Text(0.5,0,'xlabel')]

# %%
df["2017-01-01":"2017-12-31"].Close.plot()

# %%
df.Close.plot(xlim=["2017-01-01","2017-12-31"], ls="--"  , c="red")

# %% [markdown]
# ## Fomarting dates

# %%
from  matplotlib import  dates

# %%
df.Close.plot(xlim=["2017-01-01","2017-03-01"  ], ylim=[50,60],  figsize=(12,4))

# %% [markdown]
# ## xtick

# %%
ax = df.Close.plot(ylim=[50,60], xlim=["2017-01-01",  "2017-03-31"],  figsize=(12,4))
ax.set(xlabel="")
#mayor axis
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter("%d")) 

##menoraxis

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter("\n\n%b"))

ax.xaxis.grid(True)
ax.yaxis.grid(True)
